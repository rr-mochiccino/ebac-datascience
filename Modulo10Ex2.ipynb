# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("M:\Website_Port\ebac-datascience\previsao_de_renda.csv", index_col = 0)

# %%
dados.head()
# Out:
#      data_ref  index sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01   8682    F             False             True           1
# 1  2015-01-01  12830    M              True             True           0
# 2  2015-01-01   2885    M              True             True           2
# 3  2015-01-01  16168    F              True            False           0
# 4  2015-01-01  12438    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %%
sns.clustermap((dados.corr()), figsize = (10,8), center = 0, cmap ='Spectral')
# Out:
# C:\Users\Mimi Renno\AppData\Local\Temp\ipykernel_18592\3736502748.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.clustermap((dados.corr()), figsize = (10,8), center = 0, cmap ='Spectral')

# %%
dados.corr()
# Out:
# C:\Users\Mimi Renno\AppData\Local\Temp\ipykernel_18592\264558373.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.corr()
#                           index  posse_de_veiculo  posse_de_imovel  \
# index                  1.000000         -0.007542        -0.099683
# posse_de_veiculo      -0.007542          1.000000        -0.014727
# posse_de_imovel       -0.099683         -0.014727         1.000000
# qtd_filhos             0.039734          0.107959        -0.002525
# idade                 -0.047971         -0.157837         0.122667
# tempo_emprego         -0.034574         -0.087514         0.000112
# qt_pessoas_residencia  0.041818          0.156009        -0.007180
# mau                    0.130691         -0.017617        -0.022499
# renda                 -0.001740          0.063414         0.029827
# ...

# %%
ax = sns.pointplot(x = "posse_de_veiculo",y ="renda", data = dados, dodge = True, ci = 90)

# %%
ax = sns.pointplot(x = "posse_de_imovel",y ="renda", data = dados, dodge = True, ci = 90)

# %% [markdown]
# Ambas as variáveis parecem indicar que se a renda é maior, é possivelment} verdade que a pessoa possua um carro e um imóvel e vice-versa - ter um imóvel ou carro pode indicar uma maior renda.
