# %% [markdown]
# # Regressão 01 - tarefa 01

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as smf
from sklearn.metrics import r2_score

# %% [markdown]
# ### 1. Explorando a base de gorjetas
#
# a. Na aula fizemos uma regressão de ```tip``` explicada por ```net_bill```. Carregue os pacotes e a base, crie as variáveis necessárias como na aula, e reproduza esta regressão.
#
# b. Reproduza também o gráfico de dispersão dessas duas variáveis.

# %%
tips = sns.load_dataset("tips")
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips['net_bill'] = tips['total_bill'] - tips['tip']
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct  net_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204     15.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244      8.68
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886     17.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494     20.37
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069     20.98

# %%
sns.regplot(y = 'tip', x = 'net_bill', data = tips[tips['tip_pct']<.5])
x = np.linspace(0,tips['net_bill'].max(),100)
y = .1*x
plt.plot(x, y, '-r', label='10%')
plt.xlim(left = 0)
plt.ylim(bottom = 0)
# Out:
# (0.0, 10.5)

# %% [markdown]
# ### 2. Mudança de perspectiva
#
# Agora ajuste um modelo de regressão de ```tip_pct``` por ```net_bill```. Construa o gráfico de dispersão correspondente.

# %%
sns.regplot(y = 'tip_pct', x = 'net_bill', data = tips[tips['tip_pct']<.5])
plt.xlim(left = 0)
plt.ylim(bottom = 0)
# Out:
# (0.0, 0.505398619388979)

# %% [markdown]
# ### 3. Comente
#
# Compare os dois gráficos e comente (de forma objetiva e suscinta) a relação entre eles e a diferença do ajuste. Podemos comparar diretamente os $R^2$s?

# %% [markdown]
# No gráfico 01, quanto maior a conta, maior o valor da gorjeta, já o gráfico 02 é o oposto: quanto mais a conta aumenta, menor é a porcentagem da gorjeta.
# Não é apropriado comparar diretamente os valores de $R^2$ entre esses dois gráficos, pois $R^2$ é uma medida de ajuste que avalia a proporção da variabilidade na variável dependente explicada pelo modelo. A natureza inversa das relações nos gráficos podem levar a interpretações equivocadas se compararmos os $R^2$ diretamente.

# %% [markdown]
# ### 4. Ajuste do modelo em outra escala
#
# Com o modelo no item 3, obtenha a preditiva do valor da gorjeta:
#   1. obtenha o valor predito ```pred``` para ```tip_pct``` (dica, veja o atributo ```reg.fittedvalues```)
#   2. obtenha o valor predito para ```tip``` como ```tip_pct * net_bill```
#   3. calcule o $R^2$ do modelo para ```tip```
#   4. compare esse $R^2$ com o do item 1

# %%
reg = smf.ols('tip_pct ~ net_bill', data = tips).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                tip_pct   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     24.31
# Date:                Sat, 09 Mar 2024   Prob (F-statistic):           1.52e-06
# Time:                        10:23:14   Log-Likelihood:                 108.00
# No. Observations:                 244   AIC:                            -212.0
# Df Residuals:                     242   BIC:                            -205.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3053      0.023     13.166      0.000       0.260       0.351
# ...

# %%
reg.fittedvalues
# Out:
# 0      0.207087
# 1      0.251951
# 2      0.197684
# 3      0.180107
# 4      0.176358
#          ...
# 239    0.163268
# 240    0.150546
# 241    0.178264
# 242    0.206534
# 243    0.208316
# Length: 244, dtype: float64

# %%
pred_tip_pct = reg.fittedvalues
pred_tip_pct * tips['net_bill'].values
# Out:
# 0      3.309254
# 1      2.186938
# 2      3.461450
# 3      3.668785
# 4      3.699998
#          ...
# 239    3.773120
# 240    3.790751
# 241    3.684707
# 242    3.319003
# 243    3.287232
# Length: 244, dtype: float64

# %%
pred_tip = pred_tip_pct * tips['net_bill'].values
pred_tip
# Out:
# 0      3.309254
# 1      2.186938
# 2      3.461450
# 3      3.668785
# 4      3.699998
#          ...
# 239    3.773120
# 240    3.790751
# 241    3.684707
# 242    3.319003
# 243    3.287232
# Length: 244, dtype: float64

# %%
r2_score(tips['tip'].values, pred_tip)
# Out:
# 0.1088997484546137

# %%
r2_score(pred_tip, pred_tip_pct)
# Out:
# -19.588987135489702
