# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib notebook


sinasc = pd.read_csv('sinasc_RO_2019.csv',sep = ',')
sinasc.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
plt.rc('figure', figsize = (12,10))
fig, axes = plt.subplots(3,2)


#com seaborn countplot

sns.countplot(ax = axes[0,0], x = 'APGAR1', data = sinasc)
sns.countplot(ax = axes[0,1], x = 'APGAR5', data = sinasc)
sns.countplot(ax = axes[1,0], x = 'SEXO', data = sinasc)
sns.countplot(ax = axes[2,0], x = 'GESTACAO', data = sinasc )
sns.countplot(ax = axes[1,1], x = 'ESTCIVMAE', data = sinasc )


#legenda

axes[2, 0].tick_params(axis='x', labelrotation=45, labelsize=7)

axes[2, 1].axis('off')



plt.subplots_adjust(wspace=0.5, hspace=0.5)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
plt.close('all')
plt.rc('figure', figsize = (6,4))

fig, axes = plt.subplots(1,1)

ax = sns.barplot(x = 'CONSULTAS', y = 'APGAR5', data = sinasc, ci = None)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
plt.close('all')
plt.rc('figure', figsize = (10, 8))
fig, axes = plt.subplots (2,2)





#paleta de cores
colors_b = sns.color_palette("Blues_r", 7)
colors_v = sns.color_palette('viridis', len(freq))

#graficos 

#barra

sns.countplot(x = 'GESTACAO', data = sinasc, palette = colors_b, ax = axes[1,0])


sns.countplot(x = 'SEXO', data = sinasc, ax = axes[0,1])


#treemap
freq = sinasc['ESTCIVMAE'].value_counts()
squarify.plot(sizes= freq, label=freq.index, alpha=0.7, color =  colors_v, ax = axes [0,0])



#pie
sinasc['CONSULTAS'].value_counts().plot.pie(ax=axes[1, 1])



#legenda
axes[1, 1].set_aspect('equal') 
axes[1, 0].tick_params(axis='x', labelrotation=45, labelsize=7)




plt.subplots_adjust(wspace=0.5, hspace=0.5)

plt.tight_layout()


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
